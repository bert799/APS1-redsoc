# %%
# Importando bibliotecas necessárias para a construção de grafos
import netpixi
from netpixi.integration.gt import *
import pandas as pd
import numpy as np
import csv
import ast
# Out:
#     <script src="/files/netpixi.min.js"></script>
# <frozen importlib._bootstrap>:914: ImportWarning: VendorImporter.find_spec() not found; falling back to find_module()

# %%
df = pd.read_csv('./Video_Games_Sales_as_at_22_Dec_2016.csv')
df.dropna(subset=['Publisher'], inplace=True)
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16665 rows x 16 columns]

# %%
df.groupby('Genre')['Name'].count().sort_values(ascending=False)
# Out:
# Genre
# Action          3364
# Sports          2345
# Misc            1723
# Role-Playing    1499
# Shooter         1321
# Adventure       1299
# Racing          1248
# Platform         887
# Simulation       870
# Fighting         847
# Strategy         680
# Puzzle           580
# Name: Name, dtype: int64

# %%
df_grouped_Genre = df.groupby(['Genre']).agg({'Global_Sales': np.mean})
df_grouped_Genre.sort_values('Global_Sales', ascending=False)
# Out:
#               Global_Sales
# Genre
# Platform          0.933033
# Shooter           0.797048
# Role-Playing      0.623316
# Racing            0.584046
# Sports            0.567343
# Fighting          0.524522
# Action            0.518564
# Misc              0.461619
# Simulation        0.448483
# Puzzle            0.419000
# Strategy          0.256191
# Adventure         0.182771

# %%
sports_mean_sales = df_grouped_Genre.loc['Sports']['Global_Sales']
action_mean_sales = df_grouped_Genre.loc['Action']['Global_Sales'] 
rpg_mean_sales = df_grouped_Genre.loc['Role-Playing']['Global_Sales']

# %%
def segregate_genre_to_list(df, genre, df_list, threshold=None):
    seg_df = df[df['Genre'] == genre]
    if threshold:
        seg_df = seg_df[seg_df['Global_Sales'] > threshold]
    df_list.append(seg_df)

# %%
sorted_years = df['Year_of_Release'].unique()
sorted_years.sort()
print(sorted_years)
# Out:
# [1980. 1981. 1982. 1983. 1984. 1985. 1986. 1987. 1988. 1989. 1990. 1991.
#  1992. 1993. 1994. 1995. 1996. 1997. 1998. 1999. 2000. 2001. 2002. 2003.
#  2004. 2005. 2006. 2007. 2008. 2009. 2010. 2011. 2012. 2013. 2014. 2015.
#  2016. 2017. 2020.   nan]

# %%
df_list = []
sport_df_list = []
action_df_list = []
rpg_df_list = []
for i in range(0, len(sorted_years), 5):
    df_list.append(df[df['Year_of_Release'].isin(sorted_years[i:i+5])])

for db in df_list:
    segregate_genre_to_list(db, 'Sports', sport_df_list, threshold=sports_mean_sales)
    segregate_genre_to_list(db, 'Action', action_df_list, threshold=action_mean_sales)
    segregate_genre_to_list(db, 'Role-Playing', rpg_df_list, threshold=rpg_mean_sales)

# %%
publisher_platforms = []
for db in rpg_df_list:
    publisher_platforms.append(db.groupby('Platform')['Publisher'].unique().to_dict())

# %%
action_publishers = df[df['Genre'] == 'Action']["Publisher"].unique()
rpg_publishers = df[df['Genre'] == 'Role-Playing']["Publisher"].unique()
sports_publishers = df[df['Genre'] == 'Sports']["Publisher"].unique()

# %%
action_graph = Graph(directed=False) # não-dirigido

for publisher in action_publishers:
    print(publisher)
    action_graph.add_vertex(publisher)
# Out:
# Take-Two Interactive
# Nintendo
# Electronic Arts
# Sony Computer Entertainment
# Ubisoft
# GT Interactive
# Konami Digital Entertainment
# Sony Computer Entertainment Europe
# Virgin Interactive
# LucasArts
# Warner Bros. Interactive Entertainment
# Eidos Interactive
# Capcom
# Atari
# Activision
# Palcom
# Hasbro Interactive
# THQ
# Disney Interactive Studios
# Sega
# Square Enix
# Deep Silver
# NCSoft
# Level 5
# Parker Bros.
# Tecmo Koei
# Microsoft Game Studios
# Bethesda Softworks
# Vivendi Games
# 989 Studios
# Hello Games
# D3Publisher
# Namco Bandai Games
# 3DO
# Black Label Games
# Ocean
# Midway Games
# Hudson Soft
# Universal Interactive
# Koch Media
# Unknown
# Marvelous Entertainment
# Square Enix
# mixi, Inc
# Ubisoft Annecy
# Mystique
# 20th Century Fox Video Games
# Men-A-Vision
# Touchstone
# Majesco Entertainment
# Illusion Softworks
# Tigervision
# 505 Games
# Mattel Interactive
# TDK Mediactive
# Rondomedia
# Universal Gamex
# Wizard Video Games
# Coleco
# Rising Star Games
# CPG Products
# Infogrames
# Gamebridge
# Answer Software
# Fox Interactive
# Psygnosis
# Activision Blizzard
# Wanadoo
# BAM! Entertainment
# Interplay
# Screenlife
# Titus
# Data Age
# Imagic
# Codemasters
# Scholastic Inc.
# Laguna
# Zoo Digital Publishing
# ITT Family Games
# Ackkstudios
# Starpath Corp.
# City Interactive
# Avanquest
# CokeM Interactive
# CBS Electronics
# Hamster Corporation
# Empire Interactive
# Ignition Entertainment
# Spike
# Conspiracy Entertainment
# Acclaim Entertainment
# Nippon Ichi Software
# Nihon Falcom Corporation
# Taito
# Knowledge Adventure
# American Softworks
# Kemco
# GungHo
# Bomb
# Nordic Games
# Tomy Corporation
# Agetec
# Zoo Games
# Agatsuma Entertainment
# SCi
# TDK Core
# Destineer
# Kadokawa Games
# Video System
# SouthPeak Games
# Marvelous Interactive
# Crave Entertainment
# Adeline Software
# GameMill Entertainment
# Blast! Entertainment Ltd
# Gremlin Interactive Ltd
# Playlogic Game Factory
# Nippon Columbia
# DTP Entertainment
# Avalon Interactive
# PlayV
# Vir2L Studios
# PQube
# Telltale Games
# Excalibur Publishing
# Hip Interactive
# Rocket Company
# Banpresto
# Mindscape
# Black Bean Games
# SCS Software
# Telstar
# Crytek
# Acquire
# Broccoli
# Takara Tomy
# Idea Factory International
# Global Star
# Oxygen Interactive
# Kalypso Media
# Microids
# Core Design Ltd.
# Jaleco
# Little Orbit
# Game Factory
# Seventh Chord
# Popcorn Arcade
# Abylight
# FuRyu
# Insomniac Games
# Alchemist
# Irem Software Engineering
# Sunrise Interactive
# Xseed Games
# Atlus
# Enix Corporation
# Evolution Games
# Success
# Kadokawa Shoten
# Funbox Media
# Genki
# Gamecock
# JVC
# Crimson Cow
# Takara
# JoWood Productions
# Starfish
# 5pb
# Idea Factory
# Nordcurrent
# Marvel Entertainment
# Swing! Entertainment
# Aksys Games
# From Software
# ASC Games
# NewKidCo
# Activision Value
# Astragon
# Midas Interactive Entertainment
# Electronic Arts Victor
# Red Storm Entertainment
# Nobilis
# Rebellion Developments
# Compile Heart
# MTO
# ChunSoft
# DSI Games
# Flashpoint Games
# Games Workshop
# Maximum Family Games
# Big Fish Games
# Berkeley
# Destination Software, Inc
# LSP Games
# FuRyu Corporation
# Kaga Create
# Introversion Software
# Sold Out
# Encore
# Quinrose
# Russel
# Prototype
# Avanquest Software
# Licensed 4U
# Tru Blu Entertainment
# Views
# Minato Station
# Alternative Software
# Arc System Works
# Epic Games
# Stainless Games
# Comfort
# UFO Interactive
# Cave
# IE Institute
# Zushi Games
# CyberFront
# Asgard
# Saurus
# Essential Games
# Giza10
# Mycom
# Alawar Entertainment
# Neko Entertainment
# LEGO Media
# Yacht Club Games
# Storm City Games
# Inti Creates
# Focus Home Interactive
# dramatic create
# Yeti
# NetRevo
# Focus Multimedia
# HuneX
# Red Flagship

# %%
for i in publisher_platforms:
    print(i)
# Out:
# {}
# {'GB': array(['SquareSoft'], dtype=object), 'NES': array(['Enix Corporation', 'Capcom', 'Namco Bandai Games', 'SquareSoft'],
#       dtype=object)}
# {'GB': array(['SquareSoft'], dtype=object), 'NES': array(['Enix Corporation', 'SquareSoft'], dtype=object), 'SNES': array(['SquareSoft', 'Enix Corporation', 'Square', 'Nintendo', 'ChunSoft'],
#       dtype=object)}
# {'GB': array(['Nintendo', 'Eidos Interactive', 'Enix Corporation'], dtype=object), 'PC': array(['Activision'], dtype=object), 'PS': array(['Sony Computer Entertainment', 'SquareSoft',
#        'Konami Digital Entertainment', 'Namco Bandai Games', 'Capcom',
#        'Enix Corporation', 'Square EA', 'Square'], dtype=object), 'SNES': array(['Enix Corporation', 'SquareSoft', 'Nintendo', 'Quest'],
#       dtype=object)}
# {'GB': array(['Nintendo', 'Konami Digital Entertainment', 'Enix Corporation'],
#       dtype=object), 'GBA': array(['Nintendo', 'SquareSoft', 'Square Enix', 'Infogrames', 'Capcom',
#        'Konami Digital Entertainment', 'Atari', 'Enix Corporation'],
#       dtype=object), 'GC': array(['Nintendo', 'Ubisoft'], dtype=object), 'N64': array(['Nintendo'], dtype=object), 'PC': array(['Activision', 'Vivendi Games'], dtype=object), 'PS': array(['SquareSoft', 'Enix Corporation', 'Crave Entertainment',
#        'Namco Bandai Games', 'Electronic Arts'], dtype=object), 'PS2': array(['Sony Computer Entertainment', 'Electronic Arts', 'Square Enix',
#        'Activision', 'Namco Bandai Games', 'Ubisoft', 'Enix Corporation',
#        'Sony Oznline Entertainment', 'Atari', 'Virgin Interactive',
#        'Interplay', 'Konami Digital Entertainment'], dtype=object), 'XB': array(['Ubisoft', 'Microsoft Game Studios', 'Activision'], dtype=object)}
# {'DS': array(['Nintendo', 'Square Enix', 'Sega', 'Disney Interactive Studios'],
#       dtype=object), 'GBA': array(['Nintendo', 'Capcom'], dtype=object), 'GC': array(['Nintendo'], dtype=object), 'PC': array(['Activision', 'Bethesda Softworks', 'Electronic Arts'],
#       dtype=object), 'PS2': array(['Square Enix', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Atlus',
#        'Sony Online Entertainment', 'Tecmo Koei'], dtype=object), 'PS3': array(['Square Enix', 'Bethesda Softworks', 'Ubisoft',
#        'Namco Bandai Games', 'Electronic Arts', 'Sega',
#        'Sony Computer Entertainment', 'Activision'], dtype=object), 'PSP': array(['Capcom', 'Square Enix', 'Activision', 'Sega', 'Ghostlight'],
#       dtype=object), 'Wii': array(['Nintendo', 'Square Enix'], dtype=object), 'X360': array(['Bethesda Softworks', 'Take-Two Interactive',
#        'Microsoft Game Studios', 'Electronic Arts', 'Activision',
#        'Square Enix', 'Atari', 'SouthPeak Games'], dtype=object), 'XB': array(['Microsoft Game Studios'], dtype=object)}
# {'3DS': array(['Nintendo', 'Capcom', 'Level 5', 'GungHo', 'Square Enix',
#        'Namco Bandai Games', 'Nippon Ichi Software'], dtype=object), 'DS': array(['Nintendo', 'Square Enix', 'Level 5'], dtype=object), 'PC': array(['Activision', 'Bethesda Softworks', 'Electronic Arts',
#        'Square Enix', 'Unknown'], dtype=object), 'PS3': array(['Bethesda Softworks', 'Square Enix', 'Namco Bandai Games',
#        'Activision', 'Capcom', 'Electronic Arts', 'Ubisoft', 'Sega',
#        'Sony Computer Entertainment'], dtype=object), 'PS4': array(['Electronic Arts', 'Activision', 'Square Enix'], dtype=object), 'PSP': array(['Capcom', 'Square Enix', 'Unknown'], dtype=object), 'PSV': array(['Atlus', 'Square Enix', 'Sony Computer Entertainment'],
#       dtype=object), 'Wii': array(['Square Enix', 'Nintendo'], dtype=object), 'WiiU': array(['Nintendo'], dtype=object), 'X360': array(['Bethesda Softworks', 'Microsoft Game Studios', 'Electronic Arts',
#        'Square Enix', 'Activision', 'Namco Bandai Games', 'Ubisoft',
#        'Capcom'], dtype=object), 'XOne': array(['Electronic Arts', 'Activision'], dtype=object)}
# {'3DS': array(['Nintendo', 'Square Enix'], dtype=object), 'PC': array(['Bethesda Softworks', 'Namco Bandai Games'], dtype=object), 'PS2': array(['Unknown', 'Capcom'], dtype=object), 'PS4': array(['Bethesda Softworks', 'Namco Bandai Games', 'Square Enix'],
#       dtype=object), 'WiiU': array(['Nintendo'], dtype=object), 'XOne': array(['Bethesda Softworks', 'Namco Bandai Games'], dtype=object)}

# %%
for platform_dict in publisher_platforms:
    for platform, publishers in platform_dict.items():
        for i in range(len(publishers)):
            if i != len(publishers)-1:
                next_vertex = i+1
                while(next_vertex < len(publishers)):
                    if(publishers[i] != publishers[next_vertex]):
                        try:
                            action_graph.add_edge(publishers[i], publishers[next_vertex])
                            #shared_pathogens.get_edge(publishers[i]-1, publishers[next_vertex]-1)['strength'] = 1
                        except ValueError:
                            continue
                            #shared_pathogens.get_edge(publishers[i]-1, publishers[next_vertex]-1)['strength'] += 1
                        finally:    
                            next_vertex += 1
                    else:
                        next_vertex += 1
                    
                    
print('número de arestas de g:', action_graph.num_edges())
# Out:
# número de arestas de g: 156

# %%
print('número de vértices de g:', action_graph.num_vertices())
# Out:
# número de vértices de g: 235

# %%
gt_save(action_graph, 'action_graph.net.gz')

# %%
g = gt_load('action_graph.net.gz')
m = gt_draw.sfdp_layout(g)
gt_move(g, m)
gt_save(g, 'test.net.gz')

# %%
r = netpixi.render('test.net.gz', infinite=True);
# Out:
#         <div id="BJskyWDzgy2bHGYp3BvrKC"></div>
#         <script>netpixi.render('BJskyWDzgy2bHGYp3BvrKC', 'test.net.gz', 1.7777777777777777, true, true, false);</script>
