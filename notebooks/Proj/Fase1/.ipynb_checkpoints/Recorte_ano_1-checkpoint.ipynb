# %% [markdown]
# # Recorte 1985 - 2002

# %%
# Importando bibliotecas necessárias para a construção de grafos
import netpixi
from netpixi.integration.gt import *
from regression.integration.gt import *
import pandas as pd
import numpy as np
import csv
import ast
import cpnet
from graph_tool import spectral
import seaborn as sns
import regression as reg
import cpnet

from scipy import stats
from matplotlib import pyplot as plt
from graph_tool import centrality
from graph_tool import spectral
# Out:
#     <script src="/files/netpixi.min.js"></script>
# <frozen importlib._bootstrap>:914: ImportWarning: VendorImporter.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.10/site-packages/seaborn/rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /usr/local/lib/python3.10/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <frozen importlib._bootstrap>:914: ImportWarning: VendorImporter.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.10/site-packages/seaborn/cm.py:1582: PendingDeprecationWarning: The register_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps.register(name)`` instead.
#   mpl_cm.register_cmap(_name, _cmap)
# /usr/local/lib/python3.10/site-packages/seaborn/cm.py:1583: PendingDeprecationWarning: The register_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps.register(name)`` instead.
#   mpl_cm.register_cmap(_name + "_r", _cmap_r)
# <frozen importlib._bootstrap>:914: ImportWarning: VendorImporter.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.10/site-packages/seaborn/rcmod.py:400: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /usr/local/lib/python3.10/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
df = pd.read_csv('./Video_Games_Sales_as_at_22_Dec_2016.csv')
df.dropna(subset=['Publisher'], inplace=True)
#df = df.loc[~df['Critic_Score'].isna() & ~df['User_Score'].isna() & ~df['Rating'].isna()]

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
df_recortado = df.loc[(df['Year_of_Release'] >= 1985) & (df['Year_of_Release'] <= 2002)]

# %%
df_recortado.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
df_recortado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16292 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16290 non-null  object
#  1   Platform         16292 non-null  object
#  2   Year_of_Release  16292 non-null  float64
#  3   Genre            16290 non-null  object
#  4   Publisher        16292 non-null  object
#  5   NA_Sales         16292 non-null  float64
#  6   EU_Sales         16292 non-null  float64
#  7   JP_Sales         16292 non-null  float64
#  8   Other_Sales      16292 non-null  float64
#  9   Global_Sales     16292 non-null  float64
#  10  Critic_Score     7982 non-null   float64
#  11  Critic_Count     7982 non-null   float64
#  12  User_Score       7461 non-null   float64
#  13  User_Count       7461 non-null   float64
#  14  Developer        9903 non-null   object
#  15  Rating           9766 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 2.1+ MB

# %%
df_recortado.Year_of_Release.value_counts()
# Out:
# 2008.0    1427
# 2009.0    1426
# 2010.0    1253
# 2007.0    1196
# 2011.0    1133
# 2006.0    1006
# 2005.0     934
# 2002.0     829
# 2003.0     775
# 2004.0     743
# 2012.0     653
# 2015.0     606
# 2014.0     581
# 2013.0     544
# 2016.0     500
# 2001.0     482
# 1998.0     379
# 2000.0     350
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      62
# 1992.0      43
# 1991.0      41
# 1986.0      21
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# Name: Year_of_Release, dtype: int64

# %%
publishers = df_recortado["Publisher"].unique()

# %%
sixth_console_generation_graph = Graph(directed=False) # não-dirigido
sixth_console_generation_graph.add_vp('Publisher')
sixth_console_generation_graph.add_vp('Games_released')
sixth_console_generation_graph.add_ep('strength')

for pub in publishers:
    sixth_console_generation_graph.add_vertex(pub)
    sixth_console_generation_graph.get_vertex(pub)['Publisher'] = pub
    num_games = df_recortado['Name'].loc[df_recortado["Publisher"] == pub].nunique() 
    sixth_console_generation_graph.get_vertex(pub)['Games_released'] = num_games

# %%
sorted_years = list(range(1985, 2003))
print(sorted_years)
# Out:
# [1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
df_list = []

margem = 4
for i in range(0, len(sorted_years), margem):
    df_list.append(df_recortado[df_recortado['Year_of_Release'].isin(sorted_years[i:i+margem])])

# %%
publisher_platforms = []
for db in df_list:
    publisher_platforms.append(db.groupby('Platform')['Publisher'].unique().to_dict())

# %%
# for i in df_recortado.pivot_table(columns=['Publisher', 'Platform'], aggfunc='size'):
#     print(i)
temp_dic = {}
for pub_list in db.groupby('Platform')['Publisher'].unique():
    for pub in pub_list:
        if pub in temp_dic:
            temp_dic[pub] += 1
        else:
            temp_dic[pub] = 1
            
for k in sorted(temp_dic, key=temp_dic.get, reverse=True):
    print(k, temp_dic[k])

# %%
for platform_dict in publisher_platforms:
    for platform, publishers in platform_dict.items():
        for i in range(len(publishers)):
            if i != len(publishers)-1:
                next_vertex = i+1
                while(next_vertex < len(publishers)):
                    if(publishers[i] != publishers[next_vertex] and not sixth_console_generation_graph.has_edge(publishers[i], publishers[next_vertex])):
                        sixth_console_generation_graph.add_edge(publishers[i], publishers[next_vertex])
                        sixth_console_generation_graph.get_edge(publishers[i], publishers[next_vertex])['strength'] = 1
                        next_vertex += 1
                    else:
                        sixth_console_generation_graph.get_edge(publishers[i], publishers[next_vertex])['strength'] += 1
                        next_vertex += 1

# %%
print('número de vértices de g:', sixth_console_generation_graph.num_vertices())
# Out:
# número de vértices de g: 563

# %%
print('número de arestaas de g:', sixth_console_generation_graph.num_edges())
# Out:
# número de arestaas de g: 42825

# %%
gt_save(sixth_console_generation_graph, 'sixth_console_generation_graph.net.gz')

# %%
g = gt_load('sixth_console_generation_graph.net.gz')
g = gt_clean(g)
cc = centrality.closeness(g)
g.add_vp('closeness', cc)
m = gt_draw.sfdp_layout(g)
gt_move(g, m)
gt_save(g, 'sixth_console_generation_sfdp.net.gz')

# %%
r = netpixi.render('sixth_console_generation_sfdp.net.gz', infinite=True);
# Out:
#         <div id="cK8CKekMMjks5VPwH67oBm"></div>
#         <script>netpixi.render('cK8CKekMMjks5VPwH67oBm', 'sixth_console_generation_sfdp.net.gz', 1.7777777777777777, true, true, false);</script>

# %%
r.vertex_scale('Games_released', 20, 50)
r.edge_scale('strength', 0.3, 4)
r.vertex_default(color=0xff8674, kscale = 4, bwidth=3, bcolor=0x000000)
r.edge_default(curve1=1, curve2=1)
r.vertex_set_key('Publisher')
# Out:
#         <div id="NkXwimw9LM27CYPfn5LCuM"></div>
#         <script>netpixi.call('NkXwimw9LM27CYPfn5LCuM', 'cK8CKekMMjks5VPwH67oBm', 'normalizeGraph', 'eyJ0eXBlIjogInZlcnRleCIsICJwcm9wcyI6IHsic3JjIjogIkdhbWVzX3JlbGVhc2VkIiwgIm1pbiI6IDIwLCAibWF4IjogNTB9fQo=');</script>
#         <div id="TLhZwTrCCnDAoq2krsaVr2"></div>
#         <script>netpixi.call('TLhZwTrCCnDAoq2krsaVr2', 'cK8CKekMMjks5VPwH67oBm', 'normalizeGraph', 'eyJ0eXBlIjogImVkZ2UiLCAicHJvcHMiOiB7InNyYyI6ICJzdHJlbmd0aCIsICJtaW4iOiAwLjMsICJtYXgiOiA0fX0K');</script>
#         <div id="QMbWRpU6TGbEbdZ2mCiG3g"></div>
#         <script>netpixi.call('QMbWRpU6TGbEbdZ2mCiG3g', 'cK8CKekMMjks5VPwH67oBm', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJ2ZXJ0ZXgiOiB7ImNvbG9yIjogMTY3NDYxMDAsICJrc2NhbGUiOiA0LCAiYndpZHRoIjogMywgImJjb2xvciI6IDB9fX0K');</script>
#         <div id="BH7dA3uG2wTHfjsTH6n9VP"></div>
#         <script>netpixi.call('BH7dA3uG2wTHfjsTH6n9VP', 'cK8CKekMMjks5VPwH67oBm', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJlZGdlIjogeyJjdXJ2ZTEiOiAxLCAiY3VydmUyIjogMX19fQo=');</script>
#         <div id="GYYCzXynrH89A9jfmxv5TQ"></div>
#         <script>netpixi.call('GYYCzXynrH89A9jfmxv5TQ', 'cK8CKekMMjks5VPwH67oBm', 'setGraph', 'eyJ0eXBlIjogInZlcnRleCIsICJwcm9wcyI6IHsic3JjIjogIlB1Ymxpc2hlciIsICJkc3QiOiAiX2tleSJ9fQo=');</script>

# %%
r.vertex_scale('closeness', 10, 50)
r.vertex_set_key('Publisher')
# Out:
#         <div id="WyhQCyatKruyWhQWXjQYNb"></div>
#         <script>netpixi.call('WyhQCyatKruyWhQWXjQYNb', 'cK8CKekMMjks5VPwH67oBm', 'normalizeGraph', 'eyJ0eXBlIjogInZlcnRleCIsICJwcm9wcyI6IHsic3JjIjogImNsb3NlbmVzcyIsICJtaW4iOiAxMCwgIm1heCI6IDUwfX0K');</script>
#         <div id="LLKGJJiiTHSDJZqNNsyhQR"></div>
#         <script>netpixi.call('LLKGJJiiTHSDJZqNNsyhQR', 'cK8CKekMMjks5VPwH67oBm', 'setGraph', 'eyJ0eXBlIjogInZlcnRleCIsICJwcm9wcyI6IHsic3JjIjogIlB1Ymxpc2hlciIsICJkc3QiOiAiX2tleSJ9fQo=');</script>

# %% [markdown]
# # Análise

# %%
sns.histplot(np.log(df_recortado['Global_Sales']))
# Out:
# <AxesSubplot: xlabel='Global_Sales', ylabel='Count'>

# %% [markdown]
# # Proximidade X Sucesso

# %%
df_pro_suc = df_recortado.copy()

# %%
g = gt_load("sixth_console_generation_sfdp.net.gz")

# %%
data = gt_data(g)
data.drop('Games_released', axis=1, inplace=True)
data.head()
# Out:
#                                                Publisher  closeness
# id
# Nintendo                                        Nintendo   0.675904
# Microsoft Game Studios            Microsoft Game Studios   0.620575
# Take-Two Interactive                Take-Two Interactive   0.879310
# Sony Computer Entertainment  Sony Computer Entertainment   0.745020
# Activision                                    Activision   0.933444

# %%
df_pro_suc = pd.merge(df_pro_suc, data, on = "Publisher", how = "inner")
df_pro_suc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16290
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16289 non-null  object
#  1   Platform         16291 non-null  object
#  2   Year_of_Release  16291 non-null  float64
#  3   Genre            16289 non-null  object
#  4   Publisher        16291 non-null  object
#  5   NA_Sales         16291 non-null  float64
#  6   EU_Sales         16291 non-null  float64
#  7   JP_Sales         16291 non-null  float64
#  8   Other_Sales      16291 non-null  float64
#  9   Global_Sales     16291 non-null  float64
#  10  Critic_Score     7982 non-null   float64
#  11  Critic_Count     7982 non-null   float64
#  12  User_Score       7461 non-null   float64
#  13  User_Count       7461 non-null   float64
#  14  Developer        9903 non-null   object
#  15  Rating           9766 non-null   object
#  16  closeness        16291 non-null  float64
# dtypes: float64(11), object(6)
# memory usage: 2.2+ MB

# %%
sns.scatterplot(x=df_pro_suc['closeness'], y=np.log(df_pro_suc['Global_Sales']));

# %%
sns.regplot(x=df_pro_suc['closeness'], y=np.log(df_pro_suc['Global_Sales']), scatter_kws={"color": "black"}, line_kws={"color": "red"});

# %%
result = reg.linear(data=df_pro_suc, formula='np.log(Global_Sales) ~ closeness')

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     np.log(Global_Sales)   R-squared:                       0.036
# Model:                              OLS   Adj. R-squared:                  0.036
# Method:                   Least Squares   F-statistic:                     612.6
# Date:                  Mon, 21 Nov 2022   Prob (F-statistic):          8.39e-133
# Time:                          13:23:35   Log-Likelihood:                -29025.
# No. Observations:                 16291   AIC:                         5.805e+04
# Df Residuals:                     16289   BIC:                         5.807e+04
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.4030      0.067    -50.553      0.000      -3.535      -3.271
# closeness      2.0384      0.082     24.752      0.000       1.877       2.200
# ==============================================================================
# Omnibus:                      216.991   Durbin-Watson:                   0.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.246
# Skew:                           0.283   Prob(JB):                     2.02e-49
# Kurtosis:                       2.896   Cond. No.                         12.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
result.micro_summary()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7d152">
#   <thead>
#     <tr>
#       <th id="T_7d152_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_7d152_level0_col1" class="col_heading level0 col1" >coefficient</th>
#       <th id="T_7d152_level0_col2" class="col_heading level0 col2" >std error</th>
#       <th id="T_7d152_level0_col3" class="col_heading level0 col3" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d152_row0_col0" class="data row0 col0" >closeness</td>
#       <td id="T_7d152_row0_col1" class="data row0 col1" >2.038418</td>
#       <td id="T_7d152_row0_col2" class="data row0 col2" >0.082355</td>
#       <td id="T_7d152_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
result.nano_summary()
# Out:
# <style type="text/css">
# #T_f7d6e_row0_col0 {
#   font-family: monospace;
#   text-align: left;
# }
# </style>
# <table id="T_f7d6e">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f7d6e_row0_col0" class="data row0 col0" >+2.038 (0.082) ***</td>
#     </tr>
#   </tbody>
# </table>

# %%
result.plot_residuals()
